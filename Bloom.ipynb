# %% [markdown]
# # Bloom
#
# Generative Art in Python (Samila)
#
# Jan 2023

# %%
#Install samila
pip install samila

# %%
#Import packages
import matplotlib.pyplot as plt
from samila import GenerativeImage
import random
import math
from samila import Projection
from samila import Marker

# %%
def f1(x, y): #Define function
    #Instantiate and return result
    result = random.uniform(-1,1) * x**1  - math.sin(y**1) + abs(y-x)
    return result
def f2(x, y): #Define function
    #Instantiate and return result
    result = random.uniform(-1,1) * y**1 - math.cos(x**1) + 1*x
    return result
g = GenerativeImage(f1, f2) #Instantiate g as GenerativeImage
g.generate(seed=8675309) #Invoke generate method and set seed for replication
g.plot()
g.seed
plt.show()
